# %% [markdown]
# ### Test the trained AutoEncoder

# %%
# !pip install  tensorboard==2.10.0
# Out:
# Collecting tensorboard==2.10.0
#   Downloading tensorboard-2.10.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: absl-py>=0.4 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (2.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (2.31.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard==2.10.0)
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (1.24.4)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (3.19.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (2.32.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (70.1.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard==2.10.0)
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (3.0.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from tensorboard==2.10.0) (0.43.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.10.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.10.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.10.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from markdown>=2.6.8->tensorboard==2.10.0) (8.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.10.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.10.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from werkzeug>=1.0.1->tensorboard==2.10.0) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard==2.10.0) (3.19.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.10.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sc23gd\appdata\local\anaconda3\envs\vptr\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.10.0) (3.2.2)
# Downloading tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
#    ---------------------------------------- 0.0/5.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.9 MB 660.6 kB/s eta 0:00:09
#    -- ------------------------------------- 0.3/5.9 MB 4.2 MB/s eta 0:00:02
#    ------ --------------------------------- 0.9/5.9 MB 7.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.7/5.9 MB 9.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.5/5.9 MB 11.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.4/5.9 MB 13.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.3/5.9 MB 13.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.2/5.9 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 5.9/5.9 MB 15.0 MB/s eta 0:00:00
# Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Installing collected packages: tensorboard-data-server, google-auth-oauthlib, tensorboard
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.0
#     Uninstalling tensorboard-2.14.0:
#       Successfully uninstalled tensorboard-2.14.0
# Successfully installed google-auth-oauthlib-0.4.6 tensorboard-2.10.0 tensorboard-data-server-0.6.1

# %%
# !pip install setuptools==59.5.0
# Out:
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#    ---------------------------------------- 0.0/952.4 kB ? eta -:--:--
#    - -------------------------------------- 30.7/952.4 kB 1.3 MB/s eta 0:00:01
#    ------------- -------------------------- 317.4/952.4 kB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 890.9/952.4 kB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 952.4/952.4 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.2.0
#     Uninstalling setuptools-70.2.0:
#       Successfully uninstalled setuptools-70.2.0
# Successfully installed setuptools-59.5.0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, random_split
#from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F

from pathlib import Path
import random
from datetime import datetime

from matplotlib import pyplot as plt

from model import VPTREnc, VPTRDec, VPTRDisc, init_weights
from model import GDL, MSELoss, L1Loss, GANLoss
from utils import KTHDataset, BAIRDataset, MovingMNISTDataset
from utils import VidCenterCrop, VidPad, VidResize, VidNormalize, VidReNormalize, VidCrop, VidRandomHorizontalFlip, VidRandomVerticalFlip, VidToTensor
from utils import visualize_batch_clips, save_ckpt, load_ckpt, set_seed, AverageMeters, init_loss_dict, write_summary, resume_training
from utils import set_seed, get_dataloader

set_seed(2021)

# %%
import numpy as np
import torch
from MovingMNIST import MovingMNIST
from pathlib import Path

# %%
resume_ckpt = Path("C:\\Users\\sc23gd\\Downloads\\OneDrive_1_27-07-2024\\BAIR_AE.tar") #specify your trained autoencoder checkpoint file
num_past_frames = 2
num_future_frames = 10
encH, encW, encC = 8, 8, 528
img_channels = 3 #Set to be 3 for BAIR dataset
N = 8
device = torch.device('cuda:0')
loss_name_list = ['AE_L1', 'Dtotal', 'Dfake', 'Dreal', 'AEgan']

# %%
VPTR_Enc = VPTREnc(img_channels, feat_dim = encC, n_downsampling = 3, padding_type = 'zero').to(device) #Set the padding_type to be "zero" for BAIR dataset

#Set the padding_type to be "zero" for BAIR dataset, set the out_layer to be 'Sigmoid' for MovingMNIST
VPTR_Dec = VPTRDec(img_channels, feat_dim = encC, n_downsampling = 3, out_layer = 'Tanh', padding_type = 'zero').to(device) 

init_weights(VPTR_Enc)
init_weights(VPTR_Dec)

loss_dict, start_epoch = resume_training({'VPTR_Enc': VPTR_Enc, 'VPTR_Dec': VPTR_Dec}, 
                                         {}, resume_ckpt, loss_name_list)
# Out:
# initialize network with normal
# initialize network with normal

# %%
_, _, test_loader, renorm_transform = get_dataloader('BAIR', N, 'C:\\VPTR_jigsaws_working\\jigsaws_suturing\\bair_format_dir', test_past_frames = 10, test_future_frames = 10, ngpus = 1, num_workers = 0)

# %%
model = nn.Sequential(VPTR_Enc, VPTR_Dec)

# %%
sample = next(iter(test_loader))
past_frames, future_frames = sample
past_frames = past_frames.to(device)
future_frames = future_frames.to(device)
x = torch.cat([past_frames, future_frames], dim = 1 )
pred = model(x)

# %%
def plot_model_result(pred, fig_name, num_frames, n = 2):
    fig, ax = plt.subplots(1, num_frames, figsize = (num_frames, 1))
    fig.subplots_adjust(wspace=0., hspace = 0.)

    for j in range(num_frames):
        ax[j].set_axis_off()
        
        img = pred[:, j, :, :, :].clone()
        img = renorm_transform(img)
        img = torch.clamp(img, min = 0., max = 1.)
        img = img[n, ...]

        img = transforms.ToPILImage()(img)
        ax[j].imshow(img, cmap = 'gray')
    fig.savefig(f'{fig_name}.pdf', bbox_inches = 'tight')

# %%
plot_model_result(x, 'AE_gt', 12, n = 1)

# %%
plot_model_result(pred, 'AE_rec', 12, n = 1)
