# %%
# !git clone https://github.com/Ryukijano/svg.git

# %%
# %cd /kaggle/working/svg

# %%
# !python train_svg_lp.py --dataset smmnist --num_digits 2 --g_dim 128 --z_dim 10 --beta 0.0001 --data_root /path/to/data/ --log_dir /logs/will/be/saved/here/ --niter 100

# %%
# !sh data/download_bair.sh /path/to/data/
